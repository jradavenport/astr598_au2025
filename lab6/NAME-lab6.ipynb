# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Data Mixup
# Oh no, your clumsy professor mixed up the data for this lab!
#
# I downloaded the AAVSO data for 2 famous giant stars that we talked about in class: [Betelgeuse](https://en.wikipedia.org/wiki/Betelgeuse) and [Mira](https://en.wikipedia.org/wiki/Mira)... but I don't remember which is which.
#
# There are many ways to explore AAVSO data. You can plot AAVSO light curves [here](https://www.aavso.org/LCGv2/), and request data using [this form](https://www.aavso.org/data-download).
#
# # Directions
# 1. Work with a partner (make friends, do great science!) Write down who your partner is in your notebook!
# 2. Read of the AAVSO files. They're labeled `.txt`, but look in the files and find an easy way to read them.
# 3. Plot the `Band==V` light curves for both stars. JD is an annoying unit, so convert it to MJD.
# 4. Generate the periodogram for both stars. What period(s) do you see? Plot the phase-folded the data at these periods. Is the periodicity stationary, or is the star quasi-periodic?
# 5. How does the variability amplitude compare between the `V` and `R` bands?
# 6. Which star is which? How can you tell from the variability?
# 7. Can you find the "Great Dimming" event from Betelgeuse? How much dimmer is this than the "normal" behavior?
# 8. Very recently there has been [a claim](https://ui.adsabs.harvard.edu/abs/2025RNAAS...9..240T/abstract) that the pulsation period has changed after the Great Dimming. You've got the data to check this yourself, what do you think?
#      * Note: Wavelets are powerful, but annoying to get working. I would not neccesarily reccomend using them here unless you're ambitious
#      * A [Gaussian Process](https://ui.adsabs.harvard.edu/abs/2023ARA%26A..61..329A/abstract) with a periodic kernel would be a good way to fit the light curve, but can be a little tricky to use.
# 10. Rename your notebook file to YOUR name(s), export to PDF, turn in via [Dropbox upload link](https://www.dropbox.com/request/rLuVOlNl6X4ZDaBydC5l). (As with all assignments, nominally due in 1 week.)
